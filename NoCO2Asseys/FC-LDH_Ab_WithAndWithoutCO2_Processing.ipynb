# %% [markdown]
# # Import Packages

# %%
import FlowCal

import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import os
from tkinter.filedialog import askdirectory
import tkinter as tk
from ipywidgets import interact, widgets, fixed, interactive, HBox, Layout
import pickle
from sklearn.metrics import auc
import seaborn as sns
import pandas as pd
import matplotlib.ticker as ticker
import itertools

# %% [markdown]
# # Beads Calibration

# %%
# 5 ug per 1 million cells

mainP2 = 'C:/IBECPostDocDrive/2024_01_16_NCvsKR/Paper/FlowCytometry/251014 Lluis/' # Main experiment with increasing Ab concentrations

fls2 = os.listdir(mainP2)
flsFC2 = [fls2[i] for i in range(len(fls2)) if fls2[i][-3::] != 'PDF' and fls2[i] != 'Plots' and fls2[i] != 'Calibrate' and ' 4.' in fls2[i]]

flsFC2
# Out:
# ['LLuis 4.1 00215497 065.LMD',
#  'LLuis 4.2 00215498 066.LMD',
#  'LLuis 4.3 00215499 067.LMD',
#  'LLuis 4.4 00215500 068.LMD']

# %%
datsb = {}
datsGt1b = {}
datsGt2b = {}
for i in range(len(flsFC2)):
    datsb[flsFC2[i]] = FlowCal.transform.to_rfi(FlowCal.io.FCSData(mainP2+flsFC2[i]))
    
    datsGt1b[flsFC2[i]] = FlowCal.gate.high_low(datsb[flsFC2[i]], channels=['FS INT LIN', 'FL6 INT LOG'])

    datsGt2b[flsFC2[i]] = FlowCal.gate.density2d(datsGt1b[flsFC2[i]],
                                channels=['FS INT LIN', 'FL6 INT LOG'],
                                gate_fraction=0.9,
                                full_output=True)
# Out:
# c:\Users\dgomez\AppData\Local\anaconda3\Lib\site-packages\FlowCal\io.py:798: UserWarning: detected (and ignoring) additional data set ($NEXTDATA = 225365)
#   warnings.warn("detected (and ignoring) additional data set"
# c:\Users\dgomez\AppData\Local\anaconda3\Lib\site-packages\FlowCal\io.py:798: UserWarning: detected (and ignoring) additional data set ($NEXTDATA = 230261)
#   warnings.warn("detected (and ignoring) additional data set"
# c:\Users\dgomez\AppData\Local\anaconda3\Lib\site-packages\FlowCal\io.py:798: UserWarning: detected (and ignoring) additional data set ($NEXTDATA = 238001)
#   warnings.warn("detected (and ignoring) additional data set"
# c:\Users\dgomez\AppData\Local\anaconda3\Lib\site-packages\FlowCal\io.py:798: UserWarning: detected (and ignoring) additional data set ($NEXTDATA = 241565)
#   warnings.warn("detected (and ignoring) additional data set"

# %%
if os.path.isdir(mainP2+'Plots/') == False:
    os.mkdir(mainP2+'Plots/')

for i in range(len(flsFC2)):

    plt.ioff()

    fig = plt.figure()
    FlowCal.plot.density_and_hist(datsGt1b[flsFC2[i]],
                                gated_data=datsGt2b[flsFC2[i]].gated_data,
                                gate_contour=datsGt2b[flsFC2[i]].contour,
                                density_channels=['FS INT LIN', 'FL6 INT LOG'],
                                density_params={'mode':'scatter'},
                                hist_channels=['FL6 INT LOG'])
    plt.tight_layout()
    
    
    plt.savefig(mainP2+'Plots/'+flsFC2[i][0:-4]+'.png')
    plt.show()

# %%
C6L = [flsFC2[i] for i in range(len(flsFC2))]

beadsMean = {}

beadsMeanM = np.zeros((len(C6L), 3))

i = 0 # Sample

for i in range(len(C6L)):

    beadsMean[C6L[i]] = np.zeros(3)
    tmp = 0

    plt.figure()

    k = -4 # Peak
    for k in list(  range(len(datsGt2b[C6L[i]].contour)+1)  ) [-4:-1] :

        xx = [datsGt2b[C6L[i]].contour[-k][j][0]  for j in range(len(datsGt2b[C6L[i]].contour[-k])) ]
        yy = [datsGt2b[C6L[i]].contour[-k][j][1]  for j in range(len(datsGt2b[C6L[i]].contour[-k])) ]

        gtFSdw = datsGt2b[C6L[i]].gated_data[::, 'FS INT LIN'] > np.min(xx)
        gtFSup = datsGt2b[C6L[i]].gated_data[::, 'FS INT LIN'] < np.max(xx)
        gtFS = np.logical_and(gtFSdw,   gtFSup)

        gtFLdw = datsGt2b[C6L[i]].gated_data[::, 'FL6 INT LOG'] > np.min(yy)
        gtFLup = datsGt2b[C6L[i]].gated_data[::, 'FL6 INT LOG'] < np.max(yy)
        gtFL = np.logical_and(gtFLdw,   gtFLup)

        gtAl = np.logical_and(gtFS, gtFL)

        beadsMean[C6L[i]][tmp] = np.mean(datsGt2b[C6L[i]].gated_data[::, 'FL6 INT LOG'][gtAl])
        tmp += 1

        plt.hist(datsGt2b[C6L[i]].gated_data[::, 'FL6 INT LOG'][gtAl], bins =round(np.sqrt(len(datsGt2b[C6L[i]].gated_data[::, 'FL6 INT LOG'][gtAl]))))
        
        # FlowCal.plot.hist1d(datsGt2[C6L[i]].gated_data[gtAl], channel='FL6 INT LOG')

    beadsMean[C6L[i]] = np.sort(beadsMean[C6L[i]])
    beadsMeanM[i,::] = np.sort(beadsMean[C6L[i]])

    plt.ylabel("Count")
    plt.xlabel("Intensity (A.U.)")
    plt.title(C6L[i])
    plt.xscale('log')
    plt.show()

# %%
FITC = [1.32*(10**3), 3.91*(10**4), 2*(10**5)]

y = np.log(  np.reshape(beadsMeanM, np.shape(beadsMeanM)[0]*np.shape(beadsMeanM)[1])  )
x = np.log(  FITC*np.shape(beadsMeanM)[0]  )

slope, intercept, r, p, std_err = sp.stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, np.log(FITC)))




fig, ax = plt.subplots()
ax.grid(True, which="both", color='0.85')
ax.set_axisbelow(True)

ax.plot( np.arange(np.min(FITC), np.max(FITC)) ,   np.exp(myfunc(np.log(np.arange(np.min(FITC), np.max(FITC)))))   )

ax.errorbar(FITC, np.mean(beadsMeanM, axis=0), yerr=np.std(beadsMeanM, axis=0), fmt='o', c='red')

ax.set_ylabel('MFU')
ax.set_xlabel('ERF Value (APC 660/20)')
ax.set_xscale('log')
ax.set_yscale('log')
ax.spines[['right', 'top']].set_visible(False)
plt.show()

# %% [markdown]
# # Load Data

# %%
mainP = 'C:/IBECPostDocDrive/2024_01_16_NCvsKR/Paper/NoCO2Asseys/LDH/LDH_Ab_WithAndWithoutCO2/'

fls = os.listdir(mainP)
flsFC = [fls[i] for i in range(len(fls)) if fls[i][-3::] != 'PDF' and fls[i] != 'Plots' and fls2[i] != 'Calibrate' ]

flsFC
# Out:
# ['a647 AbNoCO2_1 00220089 135.LMD',
#  'a647 AbNoCO2_2 00220090 136.LMD',
#  'a647 AbNoCO2_3 00220091 137.LMD',
#  'a647 AbNoCO2_4 00220092 138.LMD',
#  'a647 Ab_1 00220101 147.LMD',
#  'a647 Ab_2 00220102 148.LMD',
#  'a647 Ab_3 00220103 149.LMD',
#  'a647 Ab_4 00220104 150.LMD',
#  'a647 ConNoCO2_1 00220097 143.LMD',
#  'a647 ConNoCO2_2 00220098 144.LMD',
#  'a647 ConNoCO2_3 00220099 145.LMD',
#  'a647 ConNoCO2_4 00220100 146.LMD',
#  'a647 IsoNoCO2_1 00220093 139.LMD',
#  'a647 IsoNoCO2_2 00220094 140.LMD',
#  'a647 IsoNoCO2_3 00220095 141.LMD',
#  'a647 IsoNoCO2_4 00220096 142.LMD',
#  'a647 Iso_1 00220105 151.LMD',
#  'a647 Iso_2 00220106 152.LMD']

# %%
dats = {}
datsGt1 = {}
datsGt2 = {}
for i in range(len(flsFC)):
    dats[flsFC[i]] = FlowCal.transform.to_rfi(FlowCal.io.FCSData(mainP+flsFC[i]))
    
    datsGt1[flsFC[i]] = FlowCal.gate.high_low(dats[flsFC[i]], channels=['FS INT LIN', 'FL6 INT LOG'])

    datsGt2[flsFC[i]] = FlowCal.gate.density2d(datsGt1[flsFC[i]],
                                channels=['FS INT LIN', 'FL6 INT LOG'],
                                gate_fraction=0.85,
                                full_output=True)
# Out:
# c:\Users\dgomez\AppData\Local\anaconda3\Lib\site-packages\FlowCal\io.py:798: UserWarning: detected (and ignoring) additional data set ($NEXTDATA = 217935)
#   warnings.warn("detected (and ignoring) additional data set"
# c:\Users\dgomez\AppData\Local\anaconda3\Lib\site-packages\FlowCal\io.py:798: UserWarning: detected (and ignoring) additional data set ($NEXTDATA = 520267)
#   warnings.warn("detected (and ignoring) additional data set"
# c:\Users\dgomez\AppData\Local\anaconda3\Lib\site-packages\FlowCal\io.py:798: UserWarning: detected (and ignoring) additional data set ($NEXTDATA = 370108)
#   warnings.warn("detected (and ignoring) additional data set"
# c:\Users\dgomez\AppData\Local\anaconda3\Lib\site-packages\FlowCal\io.py:798: UserWarning: detected (and ignoring) additional data set ($NEXTDATA = 362547)
#   warnings.warn("detected (and ignoring) additional data set"
# c:\Users\dgomez\AppData\Local\anaconda3\Lib\site-packages\FlowCal\io.py:798: UserWarning: detected (and ignoring) additional data set ($NEXTDATA = 233019)
#   warnings.warn("detected (and ignoring) additional data set"
# c:\Users\dgomez\AppData\Local\anaconda3\Lib\site-packages\FlowCal\io.py:798: UserWarning: detected (and ignoring) additional data set ($NEXTDATA = 379289)
#   warnings.warn("detected (and ignoring) additional data set"
# c:\Users\dgomez\AppData\Local\anaconda3\Lib\site-packages\FlowCal\io.py:798: UserWarning: detected (and ignoring) additional data set ($NEXTDATA = 498811)
#   warnings.warn("detected (and ignoring) additional data set"
# c:\Users\dgomez\AppData\Local\anaconda3\Lib\site-packages\FlowCal\io.py:798: UserWarning: detected (and ignoring) additional data set ($NEXTDATA = 482178)
#   warnings.warn("detected (and ignoring) additional data set"
# c:\Users\dgomez\AppData\Local\anaconda3\Lib\site-packages\FlowCal\io.py:798: UserWarning: detected (and ignoring) additional data set ($NEXTDATA = 509940)
#   warnings.warn("detected (and ignoring) additional data set"
# c:\Users\dgomez\AppData\Local\anaconda3\Lib\site-packages\FlowCal\io.py:798: UserWarning: detected (and ignoring) additional data set ($NEXTDATA = 510912)
#   warnings.warn("detected (and ignoring) additional data set"
# c:\Users\dgomez\AppData\Local\anaconda3\Lib\site-packages\FlowCal\io.py:798: UserWarning: detected (and ignoring) additional data set ($NEXTDATA = 157023)
#   warnings.warn("detected (and ignoring) additional data set"
# c:\Users\dgomez\AppData\Local\anaconda3\Lib\site-packages\FlowCal\io.py:798: UserWarning: detected (and ignoring) additional data set ($NEXTDATA = 237990)
#   warnings.warn("detected (and ignoring) additional data set"
# c:\Users\dgomez\AppData\Local\anaconda3\Lib\site-packages\FlowCal\io.py:798: UserWarning: detected (and ignoring) additional data set ($NEXTDATA = 506155)
#   warnings.warn("detected (and ignoring) additional data set"
# c:\Users\dgomez\AppData\Local\anaconda3\Lib\site-packages\FlowCal\io.py:798: UserWarning: detected (and ignoring) additional data set ($NEXTDATA = 77199)
#   warnings.warn("detected (and ignoring) additional data set"
# c:\Users\dgomez\AppData\Local\anaconda3\Lib\site-packages\FlowCal\io.py:798: UserWarning: detected (and ignoring) additional data set ($NEXTDATA = 528802)
#   warnings.warn("detected (and ignoring) additional data set"
# c:\Users\dgomez\AppData\Local\anaconda3\Lib\site-packages\FlowCal\io.py:798: UserWarning: detected (and ignoring) additional data set ($NEXTDATA = 432281)
#   warnings.warn("detected (and ignoring) additional data set"
# c:\Users\dgomez\AppData\Local\anaconda3\Lib\site-packages\FlowCal\io.py:798: UserWarning: detected (and ignoring) additional data set ($NEXTDATA = 398657)
#   warnings.warn("detected (and ignoring) additional data set"
# c:\Users\dgomez\AppData\Local\anaconda3\Lib\site-packages\FlowCal\io.py:798: UserWarning: detected (and ignoring) additional data set ($NEXTDATA = 394481)
#   warnings.warn("detected (and ignoring) additional data set"

# %% [markdown]
# # Display Data

# %%
if os.path.isdir(mainP+'Plots/') == False:
    os.mkdir(mainP+'Plots/')

for i in range(len(flsFC)):

    plt.ioff()

    fig = plt.figure()
    FlowCal.plot.density_and_hist(datsGt1[flsFC[i]],
                                gated_data=datsGt2[flsFC[i]].gated_data,
                                gate_contour=datsGt2[flsFC[i]].contour,
                                density_channels=['FS INT LIN', 'FL6 INT LOG'],
                                density_params={'mode':'scatter'},
                                hist_channels=['FL6 INT LOG'])
    plt.tight_layout()
    
    
    plt.savefig(mainP+'Plots/'+flsFC[i][0:-4]+'.png')
    plt.show()

# %% [markdown]
# # Extract and Display Data

# %%
CnsMean = {} # Data With Means of each replicate
CnsMode = {} # Data with Modes of each replicate
CnsAllT = {} # All data of all replicates together
CnsRepT = {} # All data with replicates per separate

# %% [markdown]
# ### Blank

# %%
BlankFils = [flsFC[i] for i in range(len(flsFC)) if 'a647 Con' in flsFC[i]]

CnsMean['Blank'] = np.zeros(len(BlankFils))
CnsMode['Blank'] = np.zeros(len(BlankFils))
CnsAllT['Blank'] = []
CnsRepT['Blank'] = {}

for z in range(len(BlankFils)):
    CnsMean['Blank'][z] = np.mean(datsGt2[BlankFils[z]].gated_data[::, 'FL6 INT LOG'])
    CnsMode['Blank'][z] = sp.stats.mode(datsGt2[BlankFils[z]].gated_data[::, 'FL6 INT LOG'])[0]
    CnsAllT['Blank'] = np.concatenate((CnsAllT['Blank'],  np.array(datsGt2[BlankFils[z]].gated_data[::, 'FL6 INT LOG'])))
    CnsRepT['Blank'][z] = datsGt2[BlankFils[z]].gated_data[::, 'FL6 INT LOG']

# %%
fig, ax = plt.subplots(figsize=(10,5))

for i in range(len(CnsRepT['Blank'])):
    sns.kdeplot(data=CnsRepT['Blank'][i], label = BlankFils[i], fill=True)

ax.set_xlabel("FL6 INT LOG")
ax.set_title("Blank")
ax.spines[['right', 'top']].set_visible(False)
# ax.set_xscale('log')
ax.legend()
plt.show()

# %% [markdown]
# ### Isotype

# %%
IsotypeFils = [flsFC[i] for i in range(len(flsFC)) if 'a647 Iso' in flsFC[i] and 'IsoNoCO2_2' not in flsFC[i]] # Need to remove second one due to really low sampling (clogging issues with machine)

CnsMean['Iso'] = np.zeros(len(IsotypeFils))
CnsMode['Iso'] = np.zeros(len(IsotypeFils))
CnsAllT['Iso'] = []
CnsRepT['Iso'] = {}

for z in range(len(IsotypeFils)):
    CnsMean['Iso'][z] = np.mean(datsGt2[IsotypeFils[z]].gated_data[::, 'FL6 INT LOG'])
    CnsMode['Iso'][z] = sp.stats.mode(datsGt2[IsotypeFils[z]].gated_data[::, 'FL6 INT LOG'])[0]
    CnsAllT['Iso'] = np.concatenate((CnsAllT['Iso'],  np.array(datsGt2[IsotypeFils[z]].gated_data[::, 'FL6 INT LOG'])))
    CnsRepT['Iso'][z] = datsGt2[IsotypeFils[z]].gated_data[::, 'FL6 INT LOG']

# %%
fig, ax = plt.subplots(figsize=(10,5))

for i in range(len(CnsRepT['Iso'])):
    sns.kdeplot(data=CnsRepT['Iso'][i], label = IsotypeFils[i], fill=True)

ax.set_xlabel("FL6 INT LOG")
ax.set_title("Iso")
ax.spines[['right', 'top']].set_visible(False)
# ax.set_xscale('log')
ax.legend()
plt.show()

# %% [markdown]
# ### Fluo Sample with CO2

# %%
FluoFils = [flsFC[i] for i in range(len(flsFC)) if 'a647 Ab' in flsFC[i]]

CnsMean['Fluo'] = np.zeros(len(FluoFils))
CnsMode['Fluo'] = np.zeros(len(FluoFils))
CnsAllT['Fluo'] = []
CnsRepT['Fluo'] = {}

for z in range(len(FluoFils)):
    CnsMean['Fluo'][z] = np.mean(datsGt2[FluoFils[z]].gated_data[::, 'FL6 INT LOG'])
    CnsMode['Fluo'][z] = sp.stats.mode(datsGt2[FluoFils[z]].gated_data[::, 'FL6 INT LOG'])[0]
    CnsAllT['Fluo'] = np.concatenate((CnsAllT['Fluo'],  np.array(datsGt2[FluoFils[z]].gated_data[::, 'FL6 INT LOG'])))
    CnsRepT['Fluo'][z] = datsGt2[FluoFils[z]].gated_data[::, 'FL6 INT LOG']

# %%
fig, ax = plt.subplots(figsize=(10,5))

for i in range(len(CnsRepT['Fluo'])):
    sns.kdeplot(data=CnsRepT['Fluo'][i], label = FluoFils[i], fill=True)

ax.set_xlabel("FL6 INT LOG")
ax.set_title("Fluo")
ax.spines[['right', 'top']].set_visible(False)
# ax.set_xscale('log')
ax.legend()
plt.show()

# %% [markdown]
# ### Fluo Sample with CO2

# %%
FluoFils2 = [flsFC[i] for i in range(len(flsFC)) if 'a647 AbNoCO2' in flsFC[i]]

CnsMean['Fluo_NoCO2'] = np.zeros(len(FluoFils2))
CnsMode['Fluo_NoCO2'] = np.zeros(len(FluoFils2))
CnsAllT['Fluo_NoCO2'] = []
CnsRepT['Fluo_NoCO2'] = {}

for z in range(len(FluoFils2)):
    CnsMean['Fluo_NoCO2'][z] = np.mean(datsGt2[FluoFils2[z]].gated_data[::, 'FL6 INT LOG'])
    CnsMode['Fluo_NoCO2'][z] = sp.stats.mode(datsGt2[FluoFils2[z]].gated_data[::, 'FL6 INT LOG'])[0]
    CnsAllT['Fluo_NoCO2'] = np.concatenate((CnsAllT['Fluo_NoCO2'],  np.array(datsGt2[FluoFils2[z]].gated_data[::, 'FL6 INT LOG'])))
    CnsRepT['Fluo_NoCO2'][z] = datsGt2[FluoFils2[z]].gated_data[::, 'FL6 INT LOG']

# %%
fig, ax = plt.subplots(figsize=(10,5))

for i in range(len(CnsRepT['Fluo_NoCO2'])):
    sns.kdeplot(data=CnsRepT['Fluo_NoCO2'][i], label = FluoFils[i], fill=True)

ax.set_xlabel("FL6 INT LOG")
ax.set_title("Fluo_NoCO2")
ax.spines[['right', 'top']].set_visible(False)
# ax.set_xscale('log')
ax.legend()
plt.show()

# %% [markdown]
# ### All Data Together

# %%
floCor = CnsAllT['Fluo']-(np.mean(CnsAllT['Iso'])-np.mean(CnsAllT['Blank']))
floCor_NC = CnsAllT['Fluo_NoCO2']-(np.mean(CnsAllT['Iso'])-np.mean(CnsAllT['Blank']))

# %%
mxlm = np.max([np.max(CnsAllT['Blank']), np.max(CnsAllT['Iso']), np.max(CnsAllT['Fluo'])])
mnlm = np.min([np.min(CnsAllT['Blank']), np.min(CnsAllT['Iso']), np.min(CnsAllT['Fluo'])])




########################################

kss2 = ['Blank', 'Iso', 'Fluo']
tss = [0.001, 0.01, 1]

fig, ax = plt.subplots(figsize=(10,5))

for i in range(len(kss2)):
    kde1 = sp.stats.gaussian_kde(CnsAllT[kss2[i]])
    xx1 = np.arange(np.min(CnsAllT[kss2[i]])*0.8, np.max(CnsAllT[kss2[i]]), tss[i])
    
    ax.plot(xx1, kde1(xx1) / np.max(kde1(xx1)), linewidth=2, label = kss2[i])
    plt.fill_between(x=xx1, y1=kde1(xx1)/ np.max(kde1(xx1)), alpha=0.3)

kde4 = sp.stats.gaussian_kde(floCor) # Fluorescence corrected by mean background and isotype control
xx1 = np.arange(np.min(floCor)*0.8, np.max(floCor), tss[i])
ax.plot(xx1, kde4(xx1) / np.max(kde4(xx1)), linewidth=2, label = "Fluo Corrected")
plt.fill_between(x=xx1, y1=kde4(xx1)/ np.max(kde4(xx1)), alpha=0.3)

ax.set_xlabel("FL6 INT LOG")
ax.set_ylabel("Norm. Density")
ax.set_title("Fluo")
ax.spines[['right', 'top']].set_visible(False)
ax.set_xscale('log')
ax.legend()
plt.show()

# %% [markdown]
# # Degree of labeling

# %%
DOL_Dat = pd.read_csv(r'C:\IBECPostDocDrive\2024_01_16_NCvsKR\Paper\FlowCytometry\DOL_AbsData.csv')

isoinds = [k for k in range(len(DOL_Dat["Wavelength"])) if 'Isotype' in DOL_Dat["Wavelength"][k]]
antinds = [k for k in range(len(DOL_Dat["Wavelength"])) if 'Anti' in DOL_Dat["Wavelength"][k]]

# DOL of Isotype just as a check that everything is working fine (should be same as for the anti LDH)
iso260 = np.array(DOL_Dat['260nm'][isoinds])
iso650 = np.array(DOL_Dat['650nm'][isoinds])

flu260 = np.array(DOL_Dat['260nm'][antinds])
flu650 = np.array(DOL_Dat['650nm'][antinds])

# %%
# Average DOL for Isotype Control
CF = 0.03 # Absorvance correction factor
DF = 1 # Dillution factor
eps = 210000 # Molar extinction coefficient for IgG (M-1 cm-1)
epp = 270000 # Molar extinction coefficient for fluorescent dye (M-1 cm-1)

M = ((iso260-(iso650*0.03))/eps)*DF
DOL_ISO = (iso650/(epp*M))*DF

print("Isotype Control Degree of Labeling: \n")
print("     N("+str(np.mean(DOL_ISO))+", "+str(np.std(DOL_ISO))+")")
# Out:
# Isotype Control Degree of Labeling:
#
#      N(1.0624376456533222, 0.12981141305932148)

# %%
# DOL for Isotype Control
CF = 0.03 # Absorvance correction factor
DF = 1 # Dillution factor
eps = 210000 # Molar extinction coefficient for IgG (M-1 cm-1)
epp = 270000 # Molar extinction coefficient for fluorescent dye (M-1 cm-1)

M = ((flu260-(flu650*0.03))/eps)*DF
DOL_FLU = (flu650/(epp*M))*DF

print("Anti LDH Degree of Labeling: \n")
print("     N("+str(np.mean(DOL_FLU))+", "+str(np.std(DOL_FLU))+")")
# Out:
# Anti LDH Degree of Labeling:
#
#      N(1.1755511761771886, 0.04084968960598942)

# %% [markdown]
# # Compute ERF

# %%
def myfuncRev(y):
  return (y - intercept) / slope

def compERF(slope, intercept, FITC, beadsMeanM, CEX):
    
    fig, ax = plt.subplots()
    ax.grid(True, which="both", color='0.85')
    ax.set_axisbelow(True)

    ax.plot( np.arange(np.min(FITC), np.max(FITC)) ,   np.exp(myfunc(np.log(np.arange(np.min(FITC), np.max(FITC)))))   , c='b')

    ax.errorbar(FITC, np.mean(beadsMeanM, axis=0), yerr=np.std(beadsMeanM, axis=0), fmt='o', c='red')
    
    ERF = np.zeros(len(CEX))
    if len(CEX) < 10:
      for i in range(len(CEX)):
          
          ERF[i] = np.exp(myfuncRev(np.log(CEX[i])))
          
          # ax.plot([np.min(FITC), ERF[i]], 
          #         [CEX[i], CEX[i]], c='g')
          ax.arrow(x = np.min(FITC), y = CEX[i], 
                  dx=ERF[i]*0.85, dy=0, color='g',
                  length_includes_head=True,
                  head_width = CEX[i]*0.1, head_length = ERF[i]*0.05)
          
          # ax.plot([ERF[i], ERF[i]],
          #         [CEX[i], np.min(np.mean(beadsMeanM, axis=0))], c='g')
          ax.arrow(x = ERF[i], y = CEX[i], 
                  dx=0, dy=-CEX[i]+np.min(np.mean(beadsMeanM, axis=0)), color='g',
                  length_includes_head=True,
                  head_width = ERF[i]*0.1, head_length = (CEX[0])*0.01)
          
          ax.scatter([ERF[i]], CEX[i], c='g',zorder=10)
          
    else:
      for i in range(len(CEX)):
          ERF[i] = np.exp(myfuncRev(np.log(CEX[i])))
    
      ax.arrow(x = np.min(FITC), y = np.mean(CEX), 
                  dx=np.mean(ERF)*0.85, dy=0, color='g',
                  length_includes_head=True,
                  head_width = np.mean(CEX)*0.1, head_length = np.mean(ERF)*0.05)
      ax.arrow(x = np.mean(ERF), y = np.mean(CEX), 
                    dx=0, dy=-np.mean(CEX)+np.min(np.mean(beadsMeanM, axis=0)), color='g',
                    length_includes_head=True,
                    head_width = np.mean(ERF)*0.1, head_length = np.mean(CEX)*0.01)  
      
      ax.scatter([np.mean(ERF)], np.mean(CEX), c='g',zorder=10)
      ax.set_title('Mean ERF')
    

    ax.set_ylabel('MFU')
    ax.set_xlabel('ERF Value (APC 660/20)')
    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.spines[['right', 'top']].set_visible(False)
    plt.show()
    
    return(ERF)

# %%
ERFall = compERF(slope, intercept, FITC, beadsMeanM, floCor)
print(ERFall)

NigG = ERFall/np.mean(DOL_FLU)
Nenz = NigG*2
# Out:
# [ 66335.04612233 108861.82785314  68088.87514167 ... 106987.52066343
#   53363.37578201  71115.08843781]

# %%
ERFall2 = compERF(slope, intercept, FITC, beadsMeanM, floCor_NC)
print(ERFall2)

NigG_NC = ERFall2/np.mean(DOL_FLU)
Nenz_NC = NigG_NC*2
# Out:
# [ 66335.04612233 108861.82785314  68088.87514167 ...  93918.70815442
#  130632.46465742 241838.44471318]

# %%
fig, ax = plt.subplots(figsize=(7,5))

sns.kdeplot(data=Nenz, fill=True)

ax.set_xlabel("# LDH / Cell")
ax.set_title("Fluo with CO2")
ax.spines[['right', 'top']].set_visible(False)
# ax.set_xscale('log')
# ax.legend()
plt.show()


fig, ax = plt.subplots(figsize=(7,5))

sns.kdeplot(data=Nenz_NC, fill=True)

ax.set_xlabel("# LDH / Cell")
ax.set_title("Fluo WITHOUT CO2")
ax.spines[['right', 'top']].set_visible(False)
# ax.set_xscale('log')
# ax.legend()
plt.show()

# %%
moleLDH = (Nenz/(6.023*10**23))*1e6*1e15 # Moles of LDH

fig, ax = plt.subplots(figsize=(7,5))

sns.kdeplot(data=moleLDH, fill=True)

ax.set_xlabel("fmol LDH / 1e6 Cell")
ax.set_title("Fluo")
ax.spines[['right', 'top']].set_visible(False)
# ax.set_xscale('log')
# ax.legend()
plt.show()



moleLDH2 = (Nenz_NC/(6.023*10**23))*1e6*1e15 # Moles of LDH

fig, ax = plt.subplots(figsize=(7,5))

sns.kdeplot(data=moleLDH2, fill=True)

ax.set_xlabel("fmol LDH / 1e6 Cell")
ax.set_title("Fluo WITHOUT CO2")
ax.spines[['right', 'top']].set_visible(False)
# ax.set_xscale('log')
# ax.legend()
plt.show()

# %% [markdown]
# # Save Results for Julia Plots of Supplementary Data

# %%
LDHFlu = {}
LDHFlu['CO2'] = moleLDH
LDHFlu['NoCO2'] = moleLDH2

# %%
with open('C:/IBECPostDocDrive/2024_01_16_NCvsKR/Paper/NoCO2Asseys/LDH/ProcessedData_femtomolePer1Mil.pkl', 'wb') as f:
    pickle.dump(LDHFlu, f)

# %%
pd.DataFrame(moleLDH, columns=['LDH']).to_csv('E:/IBEC/KineticRates/NoCO2Assays/ProcessedData_LDH_femtomolPer1Mil.csv', index=False)
pd.DataFrame(moleLDH2, columns=['LDH']).to_csv('E:/IBEC/KineticRates/NoCO2Assays/ProcessedData_LDH_NoCO2_femtomolPer1Mil.csv', index=False)
